# %% [markdown]
# <a href="https://colab.research.google.com/github/Evianitary18/Programming-With-Python/blob/main/Modul_4_Sesi_3_Mini_Case_(exercise_for_student).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction

# %% [markdown]
# Selamat, anda telah diterima menjadi seorang Jr. Data Analyst dari suatu perusahaan telekomunikasi ABC ! Untuk project pertama, anda diberikan data data pelanggan untuk diolah dan dianalisa. Data-data tersebut terdiri dari:
# 1. users.csv : berisi data-data diri pelanggan
# 2. messages.csv : berisi data penggunaan SMS oleh tiap pelanggan
# 3. calls.csv : data panggilan yang dilakukan oleh pelanggan
# 4. internet.csv : data penggunaan internet oleh pelanggan
# 5. plans.csv : berisi informasi paket langganan yang disediakan oleh perusahaan ABC, terdiri dari paket surf dan ultimate
#
# Tugas anda adalah untuk menjawab pertanyaan - pertanyaan di bawah ini menggunakan ilmu yang anda sudah pelajari selama ini.

# %% [markdown]
# ## Bagian 1 : Load dan cek data

# %%
# import library yang dibutuhkan

# %%
# load tiap data menggunakan bantuan pandas
df_users = ...
df_messages = ...
df_calls = ...
df_internet = ...
df_plans = ...

# %%
# tampilkan 5 baris teratas dari data pelanggan
# Out:
#    user_id first_name  last_name  age                                   city  \
# 0     1000   Anamaria      Bauer   45  Atlanta-Sandy Springs-Roswell, GA MSA
# 1     1001     Mickey  Wilkerson   28        Seattle-Tacoma-Bellevue, WA MSA
# 2     1002     Carlee    Hoffman   36   Las Vegas-Henderson-Paradise, NV MSA
# 3     1003   Reynaldo    Jenkins   52                          Tulsa, OK MSA
# 4     1004    Leonila   Thompson   40        Seattle-Tacoma-Bellevue, WA MSA
#
#      reg_date      plan churn_date
# 0  2018-12-24  ultimate        NaN
# 1  2018-08-13      surf        NaN
# 2  2018-10-21      surf        NaN
# 3  2018-01-28      surf        NaN
# 4  2018-05-23      surf        NaN

# %%
# tampilkan info dari dataframe pelanggan
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   first_name  500 non-null    object
#  2   last_name   500 non-null    object
#  3   age         500 non-null    int64
#  4   city        500 non-null    object
#  5   reg_date    500 non-null    object
#  6   plan        500 non-null    object
#  7   churn_date  34 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB

# %%
# tampilkan 5 data teratas dari dataframe messages
# Out:
#          id  user_id message_date
# 0  1000_125     1000   2018-12-27
# 1  1000_160     1000   2018-12-31
# 2  1000_223     1000   2018-12-31
# 3  1000_251     1000   2018-12-27
# 4  1000_255     1000   2018-12-26

# %%
# tampilkan info dari dataframe messages
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76051 entries, 0 to 76050
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            76051 non-null  object
#  1   user_id       76051 non-null  int64
#  2   message_date  76051 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
# tampilkan 5 baris teratas dari dataframe panggilan
# Out:
#          id  user_id   call_date  duration
# 0   1000_93     1000  2018-12-27      8.52
# 1  1000_145     1000  2018-12-27     13.66
# 2  1000_247     1000  2018-12-27     14.48
# 3  1000_309     1000  2018-12-28      5.76
# 4  1000_380     1000  2018-12-30      4.22

# %%
# tampilkan info dari dataframe panggilan
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  object
#  3   duration   137735 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ MB

# %%
# tampilkan 5 baris teratas dari dataframe internet
# Out:
#          id  user_id session_date  mb_used
# 0   1000_13     1000   2018-12-29    89.86
# 1  1000_204     1000   2018-12-31     0.00
# 2  1000_379     1000   2018-12-28   660.40
# 3  1000_413     1000   2018-12-26   270.99
# 4  1000_442     1000   2018-12-27   880.22

# %%
# tampilkan informasi dari dataframe internet
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104825 entries, 0 to 104824
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            104825 non-null  object
#  1   user_id       104825 non-null  int64
#  2   session_date  104825 non-null  object
#  3   mb_used       104825 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.2+ MB

# %%
# tampilkan dataframe plans
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %% [markdown]
# # Bagian 2 : Cleaning data dan melakukan perhitungan di tiap table

# %%
# ubahlah tipe data di kolom reg_date, churn_date, message_date, call_date,
# dan session date menjadi tipe data datetime.
# (opsional) gunakan looping untuk melakukannya!

# %%
# di dataframe panggilan, buatlah sebuat kolom yang berisi informasi bulan
# seorang customer melakukan panggilan

# %%
# buat sebuah dataframe baru yang berisi informasi total panggilan yang dilakukan
# tiap user tiap bulan. Gunakan fungsi pivot_table!
calls_per_month = ...
calls_per_month = calls_per_month.reset_index()
calls_per_month.columns = ["user_id","month","total_min_month"]

# %%
calls_per_month.head()
# Out:
#    user_id  month  total_min_month
# 0     1000     12           116.83
# 1     1001      8           171.14
# 2     1001      9           297.69
# 3     1001     10           374.11
# 4     1001     11           404.59

# %%
# di dataframe messages, buatlah sebuat kolom yang berisi informasi bulan
# seorang customer mengirimkan pesan

# %%
# buat sebuah dataframe baru yang berisi informasi total pesan terkirim untuk
# tiap user tiap bulan. Gunakan fungsi pivot_table!
messages_per_month = ...
messages_per_month = messages_per_month.reset_index()
messages_per_month.columns = ['user_id','month','num_messages_month']

# %%
messages_per_month.head()
# Out:
#    user_id  month  num_messages_month
# 0     1000     12                  11
# 1     1001      8                  30
# 2     1001      9                  44
# 3     1001     10                  53
# 4     1001     11                  36

# %%
# di dataframe internet, buatlah sebuat kolom yang berisi informasi bulan
# seorang customer menggunakan internet

# %%
# buat sebuah dataframe baru yang berisi informasi total pesan terkirim untuk
# tiap user tiap bulan. Gunakan fungsi pivot_table!
sessions_per_month = ...
sessions_per_month = sessions_per_month.reset_index()
sessions_per_month.columns = ['user_id', 'month', "mb_volume_month"]

# saat ini informasi penggunaan internet masih dalam megabyte (mb). Buatlah
# sebuah kolom baru yang berisi penggunaan internet dalam gigabyet (GB)
# notes : anggap 1 GB = 1000 mb
sessions_per_month['gb_volume_month'] = ...

# %%
sessions_per_month.head()
# Out:
#    user_id  month  mb_volume_month  gb_volume_month
# 0     1000     12          1901.47                2
# 1     1001      8          6919.15                7
# 2     1001      9         13314.82               14
# 3     1001     10         22330.49               23
# 4     1001     11         18504.30               19

# %% [markdown]
# # Bagian 3 : Gabungkan seluruh tabel dan lakukan perhitungan

# %%
# buat dataframe baru user_plan yang berisi kolom user_id, plan dan city dari
# tabel users. Kemudian merge dengan tabel df_plans berdasarkan plannya
user_plan = df_users[['user_id','plan','city']]
user_plan = ...

# %%
user_plan.head()
# Out:
#    user_id      plan                                    city  \
# 0     1000  ultimate   Atlanta-Sandy Springs-Roswell, GA MSA
# 1     1006  ultimate  San Francisco-Oakland-Berkeley, CA MSA
# 2     1008  ultimate       Orlando-Kissimmee-Sanford, FL MSA
# 3     1011  ultimate                Cleveland-Elyria, OH MSA
# 4     1013  ultimate                       Knoxville, TN MSA
#
#    messages_included  mb_per_month_included  minutes_included  \
# 0               1000                  30720              3000
# 1               1000                  30720              3000
# 2               1000                  30720              3000
# 3               1000                  30720              3000
# 4               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               70           7             0.01            0.01  ultimate
# 1               70           7             0.01            0.01  ultimate
# ...

# %%
# gabungkan tabel data panggilan per bulan, pesan per bulan, dan juga
# penggunaan internet per bulan dengan tabel user_plan di atas
# hint : gunakan parameter how = 'outer' untuk penggabungan , serta gunakan
# key user_id dan month
df_monthly = (calls_per_month
              .merge(...)
              .merge(...)
              .merge(user_plan, on='user_id')
             )

# %%
df_monthly
# Out:
#       user_id  month  total_min_month  num_messages_month  mb_volume_month  \
# 0        1000     12           116.83                11.0          1901.47
# 1        1001      8           171.14                30.0          6919.15
# 2        1001      9           297.69                44.0         13314.82
# 3        1001     10           374.11                53.0         22330.49
# 4        1001     11           404.59                36.0         18504.30
# ...       ...    ...              ...                 ...              ...
# 2288     1204     12              NaN                78.0         36730.05
# 2289     1349     10              NaN                76.0         13093.55
# 2290     1349     11              NaN                72.0         17128.26
# 2291     1349     12              NaN                61.0         13039.91
# 2292     1108     12              NaN                 NaN           233.17
#
# ...

# %%
# isi missing value di tabel df_monthly dengan nilai 0

# %%
# buatlah sebuah pivot table untuk melihat rata-rata penggunaan internet, panggilan
# dan pesan untuk tiap jenis paket langganan. Kira kira apa yang bisa
# teman teman simpulkan dari sini ?
# Out:
#           gb_volume_month  num_messages_month  total_min_month
# plan
# surf            17.037508           31.159568       404.762390
# ultimate        17.719444           37.551389       406.193083
