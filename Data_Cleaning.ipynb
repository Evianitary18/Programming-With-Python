# %% [markdown]
# <a href="https://colab.research.google.com/github/Evianitary18/Programming-With-Python/blob/main/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Cleansing:
# - mengidentifikasi bagian data yang salah, tidak lengkap, tidak akurat, tidak relevan atau hilang
#
# - Memodifikasi, mengganti, atau menghapus data-data tersebut sesuai dengan kebutuhan

# %% [markdown]
# 1. Menemukan missing data

# %%
import pandas as pd
import numpy as np

# %%
# melihat tipe data
df1.info()

# %%
# Dataset tidak diketahui woy
# jelek
# missing value gaselalu Nun, tapi bisa jadi n.a
# nah jadi perlu format ulang biar nilainya dari seragam

for col in ['Gender', 'Senioe Managemenr', 'True']:
  print(df1[col].unique[])

# %%
df1.salary.describe

# %%
missing_value_formats = ["n.a.","?","NA","n/a", "na", "--"]
df1 = pd.read_csv(url, na_values = missing_value_formats)

# %%
df.info()
# untuk mengecek lagi data dalam tabel

# %% [markdown]
# Cara mengetaui missing data:
# 1. menggunakan fungsi sum()

# %%
df1.isnull().sum()

# %% [markdown]
# 2. Menggunakan persentase %

# %%
percent_missing = df1.isnull().sum() * 100 / len(df1)
missing_value_df1 = pd.DataFrame({'column_name': df1.columns,
                                 'percent_missing': percent_missing})
missing_value_df1

# %% [markdown]
# 3. Menggunakan histogram

# %%
missing_value_df1.plot.bar(x="column_name", subplots = True)

# %%
# 4. Headmap

from matplotlib import pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,10))
sns.heatmap(df1.isnull(), yticklabels=False, cmap = 'viridis', cbar=False)

# %% [markdown]
# Cara mengatasi Missing Data

# %% [markdown]
# 1. Drop kolom yang tidak terlalu penting

# %%
colsToDrop = ['Gender', 'Senior Management']
df1.drop(colsToDrop, axis =1, inplace=True)

df1

# untuk menghilangkan pakai drop trs axis =1 itu menunjukkan bahwa ini kolom
# inplace = True artinya bahwa kita akan mengganti perubahan datanya saat itu juga ketika memanggil df1 lagi

# %% [markdown]
# 2. Kalau membuang baris data yang tidak lengkap pakai fungsi dropna

# %%
df1.dropna(inplace=True)

# %% [markdown]
# 3. Imputasi missing value dengan nilai konstan

# %%
df1.fillna({'Gender' :'Other'}, inplace=True)
# Jadi ketika data ini menemukan missing value, dia mengganti dengan other

# %%
df.head(10)

# %% [markdown]
# Untuk nilai numerik bisa diganti dengan median atau mean

# %% [markdown]
# df.Salary.describe()

# %%
df1.fillna({'Salary', 94370} inplace=True)

# %%
df1.Salary.isnull().sum()

# %% [markdown]
# Mendeteksi apakah ada outlier

# %%
#mencari oulier

import sklearn
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# lead the dataset
bos_hou =load_boston()

# create the dataframe
column_name = bos_hou.feature_names
df_boston = pd.DataFrame(bos_hou.data)
df_boston.columns = column_name
df_boston.head()

# %% [markdown]
# Menggunakan statistik deskriptif dan IQR

# %%
df_boston['DIS'].describe()

# %%
# IQR
Q1 = df_boston['DIS'].quantile(0.25)
Q3 = df_boston['DIS'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)

# %% [markdown]
# ![iqr.png](data:image/png;base64,...)

# %%
print(upper)
print(lower)

# %%
df_boston[df_boston['DIS'] >=(Q3+1.5*IQR)]

# %% [markdown]
# visualisasi dengan histogram dan plotbox

# %%
plt.figure(figsize=(10, 6))
df_boston['DIS'].hist(bins=100)

# %%
plt.figure(figsize = (10,6))
df_boston.boxplot('DIS')

# oulier dengan bentuk boxplot

# %%
# Scatter plot untuk cek outlier data berpasangan

# %% [markdown]
# ![scatter.png](data:image/png;base64,...)

# %% [markdown]
# Cara mengatasi outlier

# %%
# buang baris data yang punya outlier dengan drop

# %%
# Removing Outlier
df_boston.drop(upper[0], inplace=True)

# %% [markdown]
# Mengganti data outlier dengan data baru misalnya median![Screenshot 2024-10-29 162052.png](data:image/png;base64,...)

# %%
df_boston['DIS'] = inpute_outliers_IQR(df_boston['DIS'])

# %%
df_boston['DIS'].describe()

# %%
df_boston['DIS2'].describe()

# %% [markdown]
# Mempertahankan nilai outlier

# %%
# jika menggunakan nilai median sebagai nilai tengajh dari distribusi data yang digunakan karena nilai median tidak terpengaruh oleh keberadaan outliera
# lakukan transformasi data (misalnya dalam bentuk logarithmic), terutama jika kamu akan melakukan analisis statistik yang menggunakan asumsi normalitas
