# %% [markdown]
# <a href="https://colab.research.google.com/github/Evianitary18/Programming-With-Python/blob/main/Data_preparation_1_(Eksplorasi_data_dengan_numpy_dan_pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numpy untuk melakukan scientific computing
# pandas untuk melakukan pengolahan data

# %%
import pandas as pd
import numpy as np

# %%
# untuk membaca data
df = pd.read_csv('test_school.csv')

# %%
df

# %% [markdown]
# 1. Menghapus 1/beberapa kolom yang tidak informatif atau relevan dengan fungsi drop

# %%
# untuk melihat nama kolum
df.columns

# %%
colsToDrop['test_number', 'term_1', 'term_2', 'term_3']

df.drop(colsToDrop, axis=1, inplace=True)

# %%
df

# %% [markdown]
# 2. Mengambil Sebagian Data Menurut Indeks

# %%
df.loc[0]
# mengambil hanya 1 baris

# %%
df.loc[0:2]
# mengambil baris ke 0 sampai 2

# %%
df.loc[:,['name', 'phone']]
# mengambil kolom name dan phone

# %%
df.iloc[[1,0],[1,0]]
# iloc untuk indexing dengan menggunakan angka

# %% [markdown]
# 3. Merubah index dataframe dengan set index

# %%
df2= df.set_index('name')
df2

# %%
df2.loc['Mary']
# index tidak harus unik

# %% [markdown]
# 4. Mengembalikan index yang telah dirubah menggunakan reset index

# %%
df1.reset_index()

# %% [markdown]
# 5. Merapikan Data Frame
#
# Tiga sifat dataframe yang rapi
# 1. Setiap jenis unit pengamatan membentuk tabel
# 2. Setiap variabel membentuk kolom
# 3. setiap pengamatan membentuk 1 baris

# %%
# 1
df.columns

# %%
df_student = df[['id','name', 'phone', 'sex and age']]
# tanda kurung siku 2 kali untuk mengambli data kolom tertentu
df_student

# %%
df.head(2)

# %% [markdown]
# ![a.png](data:image/png;base64,...)

# %%
df.student

# %%
df_perf.head(5)

# %%
molten_performance_df = pd.melt(df_perf, id_vars = ['id', 'test_number'], var_name = 'term', value_name='marks')

# %%
molten_performance_df

# %%
df_student

# %%
df_student['name'] = np.where(df_student.name.str.contains('Mary '),'Maria, df_student' ['name'])

# %%
df_student[['name', 'phone']].applymap(lambda x: len(str(x)))
