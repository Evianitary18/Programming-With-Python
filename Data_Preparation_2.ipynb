# %% [markdown]
# <a href="https://colab.research.google.com/github/Evianitary18/Programming-With-Python/blob/main/Data_Preparation_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
olym = pd.read_csv("olympics.csv")
olym

# %%
olym = pd.read_csv("olympics.csv", skiprows=1)
olym

# %% [markdown]
# Rename nama kolom

# %%
# tapi sebelum itu buat mapping, nama yang mau diubah dan nama yang akan dibuat

# %% [markdown]
# ![b.png](data:image/png;base64,...)

# %%
# cara rename
olym.rename(columns=new_name, inplace = True)

# %%
olym
