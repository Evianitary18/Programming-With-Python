# %% [markdown]
# <a href="https://colab.research.google.com/github/Evianitary18/Programming-With-Python/blob/main/A_B_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disclaimer, ini merupakan rangkuman belajar dari studi independent
# sengaja ditaruh untuk dokumen kalau ingin belajar lagi
# tidak untuk diperjualbelikan dsbnya
# murni agar Nita bisa inget terus

# %% [markdown]
# ![Screenshot 2024-10-30 160330.png](data:image/png;base64,...)

# %% [markdown]
# ![00.png](data:image/png;base64,...)

# %% [markdown]
# ![problem.png](data:image/png;base64,...)

# %% [markdown]
# ![metode.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-30 160553.png](data:image/png;base64,...)

# %% [markdown]
# **A. Merumuskan Hipotesis**

# %% [markdown]
# ![hipotesis.png](data:image/png;base64,...)

# %% [markdown]
# **B. Mengumpulkan dan Menyiapkan Data**

# %% [markdown]
# ![Screenshot 2024-10-30 160852.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-30 160921.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-30 161039.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-30 161104.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-30 161145.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-30 161228.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-30 161305.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-30 161335.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-30 161402.png](data:image/png;base64,...)

# %% [markdown]
# **C. Visualisasi**

# %% [markdown]
# ![Screenshot 2024-10-30 161455.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-30 161538.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-30 161653.png](data:image/png;base64,...)

# %% [markdown]
# **D. Testing Hipotesis**
#
# ![Screenshot 2024-10-30 161744.png](data:image/png;base64,...)

# %% [markdown]
# **E. Kesimpulan**
#
# ![Screenshot 2024-10-30 161857.png](data:image/png;base64,...)
