# %% [markdown]
# <a href="https://colab.research.google.com/github/Evianitary18/Programming-With-Python/blob/main/Modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Modules adalah files yang berisi beberapa atau sekumpulan sintaks pemrograman python yang disimpan dengan file extension py

# %%
def welcome_message(course):
    print("Welcome to", course)

def jumlah(a,b):
    result = a + b
    return(result)

# %%
import modules

# %%
modules.welcome_message("Modules")
# Out:
# Welcome to Modules

# %%
from modules import welcome_message

welcome_message("Data Analys")
# Out:
# Welcome to Data Analys

# %%
from modules import jumlah

# %%
jumlah(2,3)
# Out:
# 5

# %%
# nama modules juga bisa dialiaskan jika modules nya terlalu panjang

import modules as ex

# %%
ex.jumlah(20,10)
# Out:
# 30

# %%
# Untuk memperoleh informasi lengkap tentang suatu modules pada python, kamu bisa pakai fungsi help
Python: help(nama_modul)

# %%
help(modules)
# Out:
# Help on module modules:
#
# NAME
#     modules - Modules.ipynb
#
# DESCRIPTION
#     Automatically generated by Colab.
#
#     Original file is located at
#         https://colab.research.google.com/drive/1dNoQ5Xo7AXHE9UWIjF9jvNrZOx_VNnJL
#
#     Modules adalah files yang berisi beberapa atau sekumpulan sintaks pemrograman python yang disimpan dengan file extension py
#
# FUNCTIONS
#     jumlah(a, b)
#
#     welcome_message(course)
#
# FILE
#     /content/modules.py

# %% [markdown]
# Packages adalah sebuah direktori yang digunakan untuk mengelola dan mengorganisir banyak modules, di mana ia memuat file bernama "_init_.py" di dalamnya

# %%
from luas import lingkaran, persegi
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-501058455287> in <cell line: 1>()
# ----> 1 from luas import lingkaran, persegi
#
# ModuleNotFoundError: No module named 'luas'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Library merupakan gabungan dari sekumpulan packages dan modules dengan fungsionalitas yang sama. Bersifat reusable (bisa digunakan berkali-kali dimana saja dan kapan saja)

# %% [markdown]
# Python memiliki 137000 library yang bisa digunakan secara gratis.

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data_saya = pd.read_csv("data_saya.csv")

# %% [markdown]
# ![Screenshot 2024-10-26 154948.png](data:image/png;base64,...)
